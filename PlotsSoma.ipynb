# %% [markdown]
# ## TOUCH plotting

# %%
#settings and packages 
# %matplotlib inline
import nilearn
from nilearn import datasets
from nilearn import plotting
from nilearn import image
import matplotlib.pyplot as plt
import numpy as np
import os
from nilearn.glm import threshold_stats_img

# %%
# Set WD + background image
os.chdir("/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/Figures")

#Average t1 k9 
#bg_img_k9 = "/home/gurana93/mnt/p/userdata/gurana93/data/coilcomp/plotting/averageT1_k9_coilcomp.nii"
# average t1 knee 
#bg_img_knee = "/home/gurana93/mnt/p/userdata/gurana93/data/coilcomp/plotting/averageT1_knee_coilcomp.nii"

#average t1 both coils averaged 
# none atm 

# nitzsche template 
bg_img_nitzsche = "/home/gurana93/mnt/p/userdata/gurana93/data/atlas/AnimalBrainmapping/canine_template/canine_template.nii"
bg_img_sample = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/analysis_scripts/averageT1/averageT1_22dogs_SOMA.nii"
#ROI 
roiImg = "/home/gurana93/mnt/p/userdata/gurana93/data/atlas/anat_masks/somatofigs/SCortex_grouptemplate.nii"

# %%
TouchvBL = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/TouchvBL/spmT_0002.nii"

# alpha = 0.05, 0 voxel threshold 
thr_map_TouchvsBL, threshold_TvBL= threshold_stats_img(TouchvBL, alpha=.005, height_control=None, cluster_threshold=40, two_sided = True) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'z',cut_coords = (5, 10, 15, 20, 25), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('TouchvsBL_Z_new.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'x', cut_coords = (-20, -15, -3, 0, 3, 15, 20), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')# ,vmax = 25)
display.savefig('TouchvsBL_X_new.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'y', cut_coords = (-15, -10, -5, 0, 5), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')#, vmax = 25)
display.savefig('TouchvsBL_Y_new.png', dpi = 500)
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image)

# %%
# BLvTouch
BLvTouch = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/TouchvBL/spmT_0003.nii"

# alpha = 0.05, 0 voxel threshold 
thr_map_BLvsTouch, threshold_BLvT= threshold_stats_img(BLvTouch, alpha=.005, height_control=None, cluster_threshold=40, two_sided = False) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_BLvsTouch, bg_img_sample, display_mode = 'z',cut_coords = (15, 18, 20, 22), title = "Baseline vs touch (bilateral)", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('BLvTouch_Z_new.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_BLvsTouch, bg_img_sample, display_mode = 'x', cut_coords = (-18, -15, -13, 13, 15, 18), title = "Baseline vs touch (bilateral)", symmetric_cbar = 'auto')# ,vmax = 25)
display.savefig('BLvTouch_X_new.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_BLvsTouch, bg_img_sample, display_mode = 'y', cut_coords = (0, 3, 5, 8), title = "Baseline vs touch (bilateral)", symmetric_cbar = 'auto')#, vmax = 25)
display.savefig('BLvTouch_Y_new.png', dpi = 500)
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image)

# %%
testimg = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/TouchvBL/beta_0001.nii"
#plotting.view_img(testimg, threshold=3.0)
display = plotting.plot_stat_map(testimg, bg_img_sample, display_mode = 'z',cut_coords = (-5, 0, 5, 10, 15, 20, 25))# , vmax = 25)
# Out:
# /usr/local/lib/python3.8/dist-packages/nilearn/_utils/niimg.py:63: UserWarning: Non-finite values detected. These values will be replaced with zeros.
#   warn(

# %%
# touch v bl both directions 
TouchvBL = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/TouchvBL/spmT_0002.nii"

# alpha = 0.05, 0 voxel threshold 
thr_map_TouchvsBL, threshold_TvBL= threshold_stats_img(TouchvBL, alpha=.005, height_control=None, cluster_threshold=40, two_sided = True) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'z',cut_coords = (5, 10, 15, 20, 25), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'x', cut_coords = (-20, -15, -3, 0, 3, 15, 20), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')# ,vmax = 25)
display.savefig('TouchvsBL_both_X_new.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'y', cut_coords = (-15, -10, -5, 0, 5), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')#, vmax = 25)
display.savefig('TouchvsBL_both_Y_new.png', dpi = 500)
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image)

# %% [markdown]
# ## Side comparisons

# %%
# left vs BL 
LeftvBL = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/LeftvBL/spmT_0002.nii"

# alpha = 0.05, 0 voxel threshold 
thr_map_LeftvsBL, threshold_LvBL= threshold_stats_img(LeftvBL, alpha=.005, height_control=None, cluster_threshold=50, two_sided = False) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_LeftvsBL, bg_img_sample, display_mode = 'z',cut_coords = (5, 10, 15, 20, 25), title = "Left touch vs baseline", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('LeftvsBL_Z_new.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_LeftvsBL, bg_img_sample, display_mode = 'x', cut_coords = ( -3, 0, 3, 15, 20), title = "Left touch vs baseline", symmetric_cbar = 'auto')# ,vmax = 25)
display.savefig('LeftvsBL_X_new.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_LeftvsBL, bg_img_sample, display_mode = 'y', cut_coords = (-10, -5, 0, 5), title = "Left touch vs baseline", symmetric_cbar = 'auto')#, vmax = 25)
display.savefig('LeftvsBL_Y_new.png', dpi = 500)
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image)

# %%
# left vs BL - both deactivation and activation
LeftvBL = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/LeftvBL/spmT_0002.nii"

# alpha = 0.05, 0 voxel threshold 
thr_map_LeftvsBL, threshold_LvBL= threshold_stats_img(LeftvBL, alpha=.005, height_control=None, cluster_threshold=50, two_sided = True) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_LeftvsBL, bg_img_sample, display_mode = 'z',cut_coords = (5, 10, 15, 20, 25), title = "Left touch vs baseline", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('LeftvsBL_Z_new_both.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_LeftvsBL, bg_img_sample, display_mode = 'x', cut_coords = ( -3, 0, 3, 15, 20), title = "Left touch vs baseline", symmetric_cbar = 'auto')# ,vmax = 25)
display.savefig('LeftvsBL_X_new_both.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_LeftvsBL, bg_img_sample, display_mode = 'y', cut_coords = (-10, -5, 0, 5), title = "Left touch vs baseline", symmetric_cbar = 'auto')#, vmax = 25)
display.savefig('LeftvsBL_Y_new_both.png', dpi = 500)
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image)

# %%
# Right vs BL 
RightvBL = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/RightvBL/spmT_0002.nii"

# alpha = 0.05, 0 voxel threshold 
thr_map_RightvsBL, threshold_RvBL= threshold_stats_img(RightvBL, alpha=.005, height_control=None, cluster_threshold=50, two_sided = False) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_RightvsBL, bg_img_sample, display_mode = 'z',cut_coords = (5, 10, 15), title = "Right touch vs baseline", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('RightvsBL_Z_new.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_RightvsBL, bg_img_sample, display_mode = 'x', cut_coords = (-20, -15), title = "Right touch vs baseline", symmetric_cbar = 'auto')# ,vmax = 25)
display.savefig('RightvsBL_X_new.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_RightvsBL, bg_img_sample, display_mode = 'y', cut_coords = (-10, -5), title = "Right touch vs baseline", symmetric_cbar = 'auto')#, vmax = 25)
display.savefig('RightvsBL_Y_new.png', dpi = 500)
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image)

# %%
# Right vs BL - both deactivation and activiation
RightvBL = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/RightvBL/spmT_0002.nii"

# alpha = 0.05, 0 voxel threshold 
thr_map_RightvsBL, threshold_RvBL= threshold_stats_img(RightvBL, alpha=.005, height_control=None, cluster_threshold=50, two_sided = True) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_RightvsBL, bg_img_sample, display_mode = 'z',cut_coords = (5, 10, 15, 20), title = "Right touch vs baseline", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('RightvsBL_Z_new_both.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_RightvsBL, bg_img_sample, display_mode = 'x', cut_coords = (-25, -20, -15, -10), title = "Right touch vs baseline", symmetric_cbar = 'auto')# ,vmax = 25)
display.savefig('RightvsBL_X_new_both.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_RightvsBL, bg_img_sample, display_mode = 'y', cut_coords = (-10, -5, 0, 5), title = "Right touch vs baseline", symmetric_cbar = 'auto')#, vmax = 25)
display.savefig('RightvsBL_Y_new_both.png', dpi = 500)
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image)

# %% [markdown]
# ## overlap with ROI

# %%
# touch v bl both directions 
TouchvBL = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/TouchvBL/spmT_0002.nii"
# alpha = 0.05, 0 voxel threshold 
thr_map_TouchvsBL, threshold_TvBL= threshold_stats_img(TouchvBL, alpha=.005, height_control=None, cluster_threshold=40, two_sided = True) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'z',cut_coords = (5, 10, 15, 20), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')# , vmax = 25)
#display.add_contours(img = roiImg, filled = True, antialiased = True, levels = [1, 7], colors = ('#4637c7', '#1C00ff00'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('TouchvsBL_both_Z_contours.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'x', cut_coords = (-20, -15, -3, 0, 3, 15, 20), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')# ,vmax = 25)
display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('TouchvsBL_both_X_contours.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'y', cut_coords = (-15, -10, -5, 0, 5), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')#, vmax = 25)
display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('TouchvsBL_both_Y_contours.png', dpi = 500)
###display = plotting.plot_roi(roiImg, bg_img = bg_img_nitzsche, axes = (0.3, 0.3, 5, 7), display_mode = 'z', cut_coords = (15, 20), draw_cross = False, view_type = 'contours', linewidths = 1.0) # , vmax = 25)###
###plotting.plot_stat_map(thr_map_TouchvsBL, bg_img = bg_img_nitzsche, display_mode = 'z',cut_coords = (15, 20), figure = 1,axes = (0.3, 0.3, 5, 7), symmetric_cbar = None) 
# Farbe 2: #bdc539 4637c7
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image) 

# antialiased = False, linewidth = 0.alpha = 0.7, linewidth = 0.2, alpha is transparency 
#display = plotting.plot_stat_map(dog_hrf_check_est_chess, bg_img,cut_coords = (9,-17,4.5), draw_cross = False)
#display.add_contours(img = marginal_gyri, filled = FALSE, colors = ‘#0081FF’)
# contours=1,
   #    antialiased=False,
   #     linewidth=4.0,
    #    levels=[0],
# Out:
# /usr/local/lib/python3.8/dist-packages/nilearn/plotting/displays/_axes.py:71: UserWarning: No contour levels were found within the data range.
#   im = getattr(ax, type)(data_2d.copy(),
# /usr/local/lib/python3.8/dist-packages/nilearn/plotting/displays/_axes.py:71: UserWarning: No contour levels were found within the data range.
#   im = getattr(ax, type)(data_2d.copy(),
# /usr/local/lib/python3.8/dist-packages/nilearn/plotting/displays/_axes.py:71: UserWarning: No contour levels were found within the data range.
#   im = getattr(ax, type)(data_2d.copy(),

# %%
# touch v bl both directions 
R1v4 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/right1v4/spmT_0001.nii"
# alpha = 0.05, 0 voxel threshold 
thr_map_R1v4, threshold_R1v4= threshold_stats_img(R1v4, alpha=.005, height_control=None, cluster_threshold=15, two_sided = True) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_R1v4, bg_img_sample, display_mode = 'z',cut_coords = (15, 18, 20), title = "Right touch first vs last second", symmetric_cbar = 'auto')# , vmax = 25)
#display.add_contours(img = roiImg, filled = True, antialiased = True, levels = [1, 7], colors = ('#4637c7', '#1C00ff00'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.savefig('R1v4_Z.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R1v4, bg_sample, display_mode = 'x', cut_coords = (-18,-15, -12,), title = "Right touch first vs last second", symmetric_cbar = 'auto')# ,vmax = 25)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.savefig('R1v4_X.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R1v4, bg_sample, display_mode = 'y', cut_coords = (-7, -6, -5), title = "Right touch first vs last second", symmetric_cbar = 'auto')#, vmax = 25)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.savefig('R1v4_Y.png', dpi = 500)
###display = plotting.plot_roi(roiImg, bg_img = bg_img_nitzsche, axes = (0.3, 0.3, 5, 7), display_mode = 'z', cut_coords = (15, 20), draw_cross = False, view_type = 'contours', linewidths = 1.0) # , vmax = 25)###
###plotting.plot_stat_map(thr_map_TouchvsBL, bg_img = bg_img_nitzsche, display_mode = 'z',cut_coords = (15, 20), figure = 1,axes = (0.3, 0.3, 5, 7), symmetric_cbar = None) 
# Farbe 2: #bdc539 4637c7
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image) 

# antialiased = False, linewidth = 0.alpha = 0.7, linewidth = 0.2, alpha is transparency 
#display = plotting.plot_stat_map(dog_hrf_check_est_chess, bg_img,cut_coords = (9,-17,4.5), draw_cross = False)
#display.add_contours(img = marginal_gyri, filled = FALSE, colors = ‘#0081FF’)
# contours=1,
   #    antialiased=False,
   #     linewidth=4.0,
    #    levels=[0],

# %%
# touch v bl both directions 
L1v4 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/left1v4/spmT_0001.nii"
# alpha = 0.05, 0 voxel threshold 
thr_map_L1v4, threshold_L1v4= threshold_stats_img(L1v4, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_L1v4, bg_img_sample, display_mode = 'z',cut_coords = (15, 18, 20), title = "Left touch first vs last second", symmetric_cbar = 'auto')# , vmax = 25)
#display.add_contours(img = roiImg, filled = True, antialiased = True, levels = [1, 7], colors = ('#4637c7', '#1C00ff00'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('L1v4_Z.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L1v4, bg_sample, display_mode = 'x', cut_coords = (18,15, 12), title = "Left touch first vs last second", symmetric_cbar = 'auto')# ,vmax = 25)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('L1v4_X.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L1v4, bg_sample, display_mode = 'y', cut_coords = (-7, -6, -5), title = "Left touch first vs last second", symmetric_cbar = 'auto')#, vmax = 25)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('L1v4_Y.png', dpi = 500)
###display = plotting.plot_roi(roiImg, bg_img = bg_img_nitzsche, axes = (0.3, 0.3, 5, 7), display_mode = 'z', cut_coords = (15, 20), draw_cross = False, view_type = 'contours', linewidths = 1.0) # , vmax = 25)###
###plotting.plot_stat_map(thr_map_TouchvsBL, bg_img = bg_img_nitzsche, display_mode = 'z',cut_coords = (15, 20), figure = 1,axes = (0.3, 0.3, 5, 7), symmetric_cbar = None) 
# Farbe 2: #bdc539 4637c7
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image) 

# antialiased = False, linewidth = 0.alpha = 0.7, linewidth = 0.2, alpha is transparency 
#display = plotting.plot_stat_map(dog_hrf_check_est_chess, bg_img,cut_coords = (9,-17,4.5), draw_cross = False)
#display.add_contours(img = marginal_gyri, filled = FALSE, colors = ‘#0081FF’)
# contours=1,
   #    antialiased=False,
   #     linewidth=4.0,
    #    levels=[0],

# %%
# touch v bl both directions 
L1v3 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/left1v3/spmT_0001.nii"
# alpha = 0.05, 0 voxel threshold 
thr_map_L1v3, threshold_L1v3= threshold_stats_img(L1v3, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_L1v3, bg_img_sample, display_mode = 'z',cut_coords = (15, 18, 20), title = "Left touch first vs third second", symmetric_cbar = 'auto')# , vmax = 25)
#display.add_contours(img = roiImg, filled = True, antialiased = True, levels = [1, 7], colors = ('#4637c7', '#1C00ff00'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('L1v3_Z.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L1v3, bg_sample, display_mode = 'x', cut_coords = (18,15, 12), title = "Left touch first vs third second", symmetric_cbar = 'auto')# ,vmax = 25)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('L1v3_X.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L1v3, bg_sample, display_mode = 'y', cut_coords = (-7, -6, -5), title = "Left touch first vs third second", symmetric_cbar = 'auto')#, vmax = 25)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('L1v3_Y.png', dpi = 500)
###display = plotting.plot_roi(roiImg, bg_img = bg_img_nitzsche, axes = (0.3, 0.3, 5, 7), display_mode = 'z', cut_coords = (15, 20), draw_cross = False, view_type = 'contours', linewidths = 1.0) # , vmax = 25)###
###plotting.plot_stat_map(thr_map_TouchvsBL, bg_img = bg_img_nitzsche, display_mode = 'z',cut_coords = (15, 20), figure = 1,axes = (0.3, 0.3, 5, 7), symmetric_cbar = None) 
# Farbe 2: #bdc539 4637c7
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image) 

# antialiased = False, linewidth = 0.alpha = 0.7, linewidth = 0.2, alpha is transparency 
#display = plotting.plot_stat_map(dog_hrf_check_est_chess, bg_img,cut_coords = (9,-17,4.5), draw_cross = False)
#display.add_contours(img = marginal_gyri, filled = FALSE, colors = ‘#0081FF’)
# contours=1,
   #    antialiased=False,
   #     linewidth=4.0,
    #    levels=[0],

# %%
# touch v bl both directions 
R1v3 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/right1v3/spmT_0001.nii"
# alpha = 0.05, 0 voxel threshold 
thr_map_R1v3, threshold_R1v3= threshold_stats_img(R1v3, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)
#thr_viscon_k9_func, threshold_visk9_func= threshold_stats_img(viscon_k9_func, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_anat, threshold_visknee_anat= threshold_stats_img(viscon_knee_anat, alpha=.05, height_control=None, cluster_threshold=0)
#thr_viscon_knee_func, threshold_visknee_func= threshold_stats_img(viscon_knee_func, alpha=.05, height_control=None, cluster_threshold=0)

display = plotting.plot_stat_map(thr_map_R1v3, bg_img_sample, display_mode = 'z',cut_coords = (15, 18, 20), title = "Right touch first vs third second", symmetric_cbar = 'auto')# , vmax = 25)
#display.add_contours(img = roiImg, filled = True, antialiased = True, levels = [1, 7], colors = ('#4637c7', '#1C00ff00'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('R1v3_Z.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R1v3, bg_sample, display_mode = 'x', cut_coords = (-18, -15, -12), title = "Right touch first vs third second", symmetric_cbar = 'auto')# ,vmax = 25)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('R1v3_X.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R1v3, bg_sample, display_mode = 'y', cut_coords = (-7, -6, -5), title = "Right touch first vs third second", symmetric_cbar = 'auto')#, vmax = 25)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('R1v3_Y.png', dpi = 500)
###display = plotting.plot_roi(roiImg, bg_img = bg_img_nitzsche, axes = (0.3, 0.3, 5, 7), display_mode = 'z', cut_coords = (15, 20), draw_cross = False, view_type = 'contours', linewidths = 1.0) # , vmax = 25)###
###plotting.plot_stat_map(thr_map_TouchvsBL, bg_img = bg_img_nitzsche, display_mode = 'z',cut_coords = (15, 20), figure = 1,axes = (0.3, 0.3, 5, 7), symmetric_cbar = None) 
# Farbe 2: #bdc539 4637c7
# try view.pos or sth or sym.cbar (in plotting.plot-stat_map or thresh_stats_img) 
# or thresh.image (nilearn.image) 

# antialiased = False, linewidth = 0.alpha = 0.7, linewidth = 0.2, alpha is transparency 
#display = plotting.plot_stat_map(dog_hrf_check_est_chess, bg_img,cut_coords = (9,-17,4.5), draw_cross = False)
#display.add_contours(img = marginal_gyri, filled = FALSE, colors = ‘#0081FF’)
# contours=1,
   #    antialiased=False,
   #     linewidth=4.0,
    #    levels=[0],

# %%
## plotting the FIR bins vs BL 

# R and L v BL bins 
R1 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Rplot/s1/spmT_0001.nii"
R2 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Rplot/s2/spmT_0001.nii"
R3 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Rplot/s3/spmT_0001.nii"
R4 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Rplot/s4/spmT_0001.nii"

L1 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Lplot/s1/spmT_0001.nii"
L2 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Lplot/s2/spmT_0001.nii"
L3 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Lplot/s3/spmT_0001.nii"
L4 = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Lplot/s4/spmT_0001.nii"
# alpha = 0.05, 0 voxel threshold 
thr_map_R1, threshold_R1= threshold_stats_img(R1, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)
thr_map_R2, threshold_R2= threshold_stats_img(R2, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)
thr_map_R3, threshold_R3= threshold_stats_img(R3, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)
thr_map_R4, threshold_R4= threshold_stats_img(R4, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)

thr_map_L1, threshold_L1= threshold_stats_img(L1, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)
thr_map_L2, threshold_L2= threshold_stats_img(L2, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)
thr_map_L3, threshold_L3= threshold_stats_img(L3, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)
thr_map_L4, threshold_L4= threshold_stats_img(L4, alpha= 0.05, height_control=None, cluster_threshold=10, two_sided = True) # 2 outputs: image and threshold (level)

display = plotting.plot_stat_map(thr_map_R1, bg_img_sample, display_mode = 'z',cut_coords = (-5, 0, 5 , 10, 15, 18, 20, 25), title = "Right touch First bin", symmetric_cbar = 'auto')# , vmax = 25)
#display.add_contours(img = roiImg, filled = True, antialiased = True, levels = [1, 7], colors = ('#4637c7', '#1C00ff00'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('R1_Z.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R2, bg_img_sample, display_mode = 'z',cut_coords = (-5, 0, 5 , 10, 15, 18, 20, 25), title = "Right touch Second bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('R2_Z.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R3, bg_img_sample, display_mode = 'z',cut_coords = (-5, 0, 5 , 10, 15, 18, 20, 25), title = "Right touch Third bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('R3_Z.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R4, bg_img_sample, display_mode = 'z',cut_coords = (-5, 0, 5 , 10, 15, 18, 20, 25), title = "Right touch Fourth bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('R4_Z.png', dpi = 500)

display = plotting.plot_stat_map(thr_map_L1, bg_img_sample, display_mode = 'z',cut_coords = (-5, 0, 5 , 10, 15, 18, 20, 25), title = "Left touch First bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L1_Z.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L2, bg_img_sample, display_mode = 'z',cut_coords = (-5, 0, 5 , 10, 15, 18, 20, 25), title = "Left touch Second bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L2_Z.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L3, bg_img_sample, display_mode = 'z',cut_coords = (-5, 0, 5 , 10, 15, 18, 20, 25), title = "Left touch Third bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L3_Z.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L4, bg_img_sample, display_mode = 'z',cut_coords = (-5, 0, 5 , 10, 15, 18, 20, 25), title = "Left touch Fourth bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L4_Z.png', dpi = 500)




#display = plotting.plot_stat_map(thr_map_L1v4, bg_sample, display_mode = 'x', cut_coords = (18,15, 12), title = "Left touch first vs last second", symmetric_cbar = 'auto')# ,vmax = 25)
##display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.savefig('L1v4_X.png', dpi = 500)
#display = plotting.plot_stat_map(thr_map_L1v4, bg_sample, display_mode = 'y', cut_coords = (-7, -6, -5), title = "Left touch first vs last second", symmetric_cbar = 'auto')#, vmax = 25)
##display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.savefig('L1v4_Y.png', dpi = 500)

# %%
## x cuts 

display = plotting.plot_stat_map(thr_map_R1, bg_img_sample, display_mode = 'x',cut_coords = (-24, -23, -22, -21, -20, -15, 15, 20, 21 ,22, 23, 24), title = "Right touch First bin", symmetric_cbar = 'auto')# , vmax = 25)
#display.add_contours(img = roiImg, filled = True, antialiased = True, levels = [1, 7], colors = ('#4637c7', '#1C00ff00'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('R1_x.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R2, bg_img_sample, display_mode = 'x',cut_coords = (-24, -23, -22, -21, -20, -15, 15, 20, 21 ,22, 23, 24), title = "Right touch Second bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('R2_x.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R3, bg_img_sample, display_mode = 'x',cut_coords = (-24, -23, -22, -21, -20, -15, 15, 20, 21 ,22, 23, 24), title = "Right touch Third bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('R3_x.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R4, bg_img_sample, display_mode = 'x',cut_coords = (-24, -23, -22, -21, -20, -15,  15, 20, 21 ,22, 23, 24), title = "Right touch Fourth bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('R4_x.png', dpi = 500)

display = plotting.plot_stat_map(thr_map_L1, bg_img_sample, display_mode = 'x',cut_coords = (-24, -23, -22, -21, -20, -15,  15, 20, 21 ,22, 23, 24), title = "Left touch First bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L1_x.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L2, bg_img_sample, display_mode = 'x',cut_coords = (-24, -23, -22, -21, -20, -15,  15, 20, 21 ,22, 23, 24), title = "Left touch Second bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L2_x.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L3, bg_img_sample, display_mode = 'x',cut_coords = (-24, -23, -22, -21, -20, -15,  15, 20, 21 ,22, 23, 24), title = "Left touch Third bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L3_x.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L4, bg_img_sample, display_mode = 'x',cut_coords = (-24, -23, -22, -21, -20, -15, 15, 20, 21 ,22, 23, 24), title = "Left touch Fourth bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L4_x.png', dpi = 500)

# %%
## y cuts 

display = plotting.plot_stat_map(thr_map_R1, bg_img_sample, display_mode = 'y',cut_coords = (-15, -10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10, 15), title = "Right touch First bin", symmetric_cbar = 'auto')# , vmax = 25)
#display.add_contours(img = roiImg, filled = True, antialiased = True, levels = [1, 7], colors = ('#4637c7', '#1C00ff00'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
#display.add_contours(img = roiImg, levels = [0], colors = ('#4637c7'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('R1_y.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R2, bg_img_sample, display_mode = 'y',cut_coords = (-15, -10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10, 15), title = "Right touch Second bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('R2_y.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R3, bg_img_sample, display_mode = 'y',cut_coords = (-15, -10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10, 15), title = "Right touch Third bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('R3_y.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_R4, bg_img_sample, display_mode = 'y',cut_coords = (-15, -10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10, 15), title = "Right touch Fourth bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('R4_y.png', dpi = 500)

display = plotting.plot_stat_map(thr_map_L1, bg_img_sample, display_mode = 'y',cut_coords = (-15, -10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10, 15), title = "Left touch First bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L1_y.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L2, bg_img_sample, display_mode = 'y',cut_coords = (-15, -10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10, 15), title = "Left touch Second bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L2_y.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L3, bg_img_sample, display_mode = 'y',cut_coords = (-15, -10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10, 15), title = "Left touch Third bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L3_y.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_L4, bg_img_sample, display_mode = 'y',cut_coords = (-15, -10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10, 15), title = "Left touch Fourth bin", symmetric_cbar = 'auto')# , vmax = 25)
display.savefig('L4_y.png', dpi = 500)

# %%
## overlaying general touch v BL activation with the FIR bins
# touch v bl both directions 
TouchvBL = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/TouchvBL/spmT_0002.nii"

L1cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Lplot/s1/L1_CL1235_338k.nii"
L2cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Lplot/s2/L2_CL1_78k.nii"
L3cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Lplot/s3/L3_Cl1_96k.nii"
R1cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Rplot/s1/R1_CL1_356k.nii"
R2cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Rplot/s2/R2_CL345_207k.nii"
R3cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Rplot/s3/R3_CL14_125k.nii"

thr_map_TouchvsBL, threshold_TvBL= threshold_stats_img(TouchvBL, alpha=.005, height_control=None, cluster_threshold=40, two_sided = True) # 2 outputs: image and threshold (level)
display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'z',cut_coords = (5, 10, 15, 20), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')# , vmax = 25)
display.add_contours(img = L1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)

display.savefig('TouchvsBL_FIR_z_contours.png', dpi = 500)
# red = 1st bin, green = 2nd bin, blue = 3rd bin

display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'x', cut_coords = (-20, -15, -3, 0, 3, 15, 20), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')# ,vmax = 25)
display.add_contours(img = L1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('TouchvsBL_FIR_x_contours.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'y', cut_coords = (-15, -10, -5, 0, 5), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')#, vmax = 25)
display.add_contours(img = L1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('TouchvsBL_FIR_y_contours.png', dpi = 500)
# Out:
# /usr/local/lib/python3.8/dist-packages/nilearn/plotting/displays/_axes.py:71: UserWarning: No contour levels were found within the data range.
#   im = getattr(ax, type)(data_2d.copy(),
# /usr/local/lib/python3.8/dist-packages/nilearn/plotting/displays/_axes.py:71: UserWarning: No contour levels were found within the data range.
#   im = getattr(ax, type)(data_2d.copy(),
# /usr/local/lib/python3.8/dist-packages/nilearn/plotting/displays/_axes.py:71: UserWarning: No contour levels were found within the data range.
#   im = getattr(ax, type)(data_2d.copy(),

# %%
## overlaying general touch v BL activation with the FIR bins
# touch v bl both directions 
TouchvBL = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/results_130623/TouchvBL/spmT_0002.nii"

L1cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Lplot/s1/L1_CL1235_338k.nii"
L2cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Lplot/s2/L2_CL1_78k.nii"
L3cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Lplot/s3/L3_Cl1_96k.nii"
R1cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Rplot/s1/R1_CL1_356k.nii"
R2cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Rplot/s2/R2_CL345_207k.nii"
R3cls = "/home/gurana93/mnt/p/userdata/gurana93/data/somatosensation/data_glm/secondlevel/FIR/Rplot/s3/R3_CL14_125k.nii"

thr_map_TouchvsBL, threshold_TvBL= threshold_stats_img(TouchvBL, alpha=.005, height_control=None, cluster_threshold=40, two_sided = True) # 2 outputs: image and threshold (level)
display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'z',cut_coords = (5, 10, 15, 20), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')# , vmax = 25)
display.add_contours(img = L1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)

display.savefig('TouchvsBL_FIR_z_contours.png', dpi = 500)
# red = 1st bin, green = 2nd bin, blue = 3rd bin

display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'x', cut_coords = (-20, -15, -3, 0, 3, 15, 20), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')# ,vmax = 25)
display.add_contours(img = L1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('TouchvsBL_FIR_x_contours.png', dpi = 500)
display = plotting.plot_stat_map(thr_map_TouchvsBL, bg_img_sample, display_mode = 'y', cut_coords = (-15, -10, -5, 0, 5), title = "Touch (bilateral) vs baseline", symmetric_cbar = 'auto')#, vmax = 25)
display.add_contours(img = L1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R1cls, levels = [0], colors = ('#ff1241'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R2cls, levels = [0], colors = ('#41ff12'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = L3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.add_contours(img = R3cls, levels = [0], colors = ('#1241ff'))#display.savefig('TouchvsBL_both_Z_new.png', dpi = 500)
display.savefig('TouchvsBL_FIR_y_contours.png', dpi = 500)
